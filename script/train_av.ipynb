# %%
# !./run_train_AVD.sh 2
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='AVD_Home_015_1_traj2', scene_index=2, subsample_rate=40, traj='traj2.txt')
# latent size single: 16
# loading dataset
# creating model
# start training
# [2/15000], training loss: 0.2920
# [4/15000], training loss: 0.2085
# [6/15000], training loss: 0.1987
# [8/15000], training loss: 0.1541
# model saved to ../results/AVD/AVD_Home_015_1_traj2/model_best.pth
# AVD_Home_015_1_traj2, ate: 668.9793444384773
# [10/15000], training loss: 0.1472
# [12/15000], training loss: 0.1348
# [14/15000], training loss: 0.1280
# [16/15000], training loss: 0.1233
# model saved to ../results/AVD/AVD_Home_015_1_traj2/model_best.pth
# AVD_Home_015_1_traj2, ate: 502.4666882891631
# [18/15000], training loss: 0.1164
# [20/15000], training loss: 0.1195
# ...

# %%
# !./run_train_AVD.sh 1
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj1', scene_index=1, subsample_rate=40, traj='traj1.txt')
# latent size single: 16
# loading dataset
# creating model
# start training
# [2/15000], training loss: 0.2483
# [4/15000], training loss: 0.2175
# [6/15000], training loss: 0.1864
# [8/15000], training loss: 0.1462
# model saved to ../results/AVD/Z_AVD_Home_015_1_traj1/model_best.pth
# Z_AVD_Home_015_1_traj1, ate: 580.6143456229904
# [10/15000], training loss: 0.1302
# [12/15000], training loss: 0.1315
# [14/15000], training loss: 0.1277
# [16/15000], training loss: 0.1264
# model saved to ../results/AVD/Z_AVD_Home_015_1_traj1/model_best.pth
# Z_AVD_Home_015_1_traj1, ate: 504.5631628764983
# [18/15000], training loss: 0.1220
# [20/15000], training loss: 0.1214
# ...

# %%
# !./run_train_AVD.sh 3
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj3', scene_index=3, subsample_rate=40, traj='traj3.txt')
# latent size single: 16
# loading dataset
# creating model
# start training
# [2/15000], training loss: 0.2612
# [4/15000], training loss: 0.1825
# [6/15000], training loss: 0.1483
# [8/15000], training loss: 0.1383
# model saved to ../results/AVD/Z_AVD_Home_015_1_traj3/model_best.pth
# Z_AVD_Home_015_1_traj3, ate: 305.4588730167148
# [10/15000], training loss: 0.1292
# [12/15000], training loss: 0.1224
# [14/15000], training loss: 0.1183
# [16/15000], training loss: 0.1164
# model saved to ../results/AVD/Z_AVD_Home_015_1_traj3/model_best.pth
# Z_AVD_Home_015_1_traj3, ate: 302.08011599059324
# [18/15000], training loss: 0.1124
# [20/15000], training loss: 0.1116
# ...

# %%
# !./run_train_AVD.sh 4
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj4', scene_index=4, subsample_rate=40, traj='traj4.txt')
# latent size single: 16
# loading dataset
# creating model
# start training
# [2/15000], training loss: 0.2380
# [4/15000], training loss: 0.1913
# [6/15000], training loss: 0.1750
# [8/15000], training loss: 0.1499
# model saved to ../results/AVD/Z_AVD_Home_015_1_traj4/model_best.pth
# Z_AVD_Home_015_1_traj4, ate: 468.02842211820024
# [10/15000], training loss: 0.1475
# [12/15000], training loss: 0.1430
# [14/15000], training loss: 0.1390
# [16/15000], training loss: 0.1348
# model saved to ../results/AVD/Z_AVD_Home_015_1_traj4/model_best.pth
# Z_AVD_Home_015_1_traj4, ate: 524.6397699165657
# [18/15000], training loss: 0.1236
# [20/15000], training loss: 0.1253
# ...

# %%
# !./run_train_AVD.sh 5
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj5', scene_index=5, subsample_rate=40, traj='traj5.txt')
# latent size single: 16
# loading dataset
# creating model
# start training
# [2/15000], training loss: 0.2795
# [4/15000], training loss: 0.1806
# [6/15000], training loss: 0.1522
# [8/15000], training loss: 0.1258
# model saved to ../results/AVD/Z_AVD_Home_015_1_traj5/model_best.pth
# Z_AVD_Home_015_1_traj5, ate: 438.21559383269243
# [10/15000], training loss: 0.1351
# [12/15000], training loss: 0.1274
# [14/15000], training loss: 0.1277
# [16/15000], training loss: 0.1237
# model saved to ../results/AVD/Z_AVD_Home_015_1_traj5/model_best.pth
# Z_AVD_Home_015_1_traj5, ate: 368.6389440706041
# [18/15000], training loss: 0.1151
# [20/15000], training loss: 0.1170
# ...

# %%
# !./run_train_AVD.sh 6
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj6', scene_index=6, subsample_rate=40, traj='traj6.txt')
# latent size single: 16
# loading dataset
# creating model
# start training
# [2/15000], training loss: 0.2292
# [4/15000], training loss: 0.2065
# [6/15000], training loss: 0.1965
# [8/15000], training loss: 0.1814
# model saved to ../results/AVD/Z_AVD_Home_015_1_traj6/model_best.pth
# Z_AVD_Home_015_1_traj6, ate: 398.8675400291292
# [10/15000], training loss: 0.1460
# [12/15000], training loss: 0.1445
# [14/15000], training loss: 0.1405
# [16/15000], training loss: 0.1337
# model saved to ../results/AVD/Z_AVD_Home_015_1_traj6/model_best.pth
# Z_AVD_Home_015_1_traj6, ate: 487.48870595571185
# [18/15000], training loss: 0.1276
# [20/15000], training loss: 0.1258
# ...

# %%
# !./run_train_AVD.sh 7
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj7', scene_index=7, subsample_rate=40, traj='traj7.txt')
# latent size single: 16
# loading dataset
# creating model
# start training
# [2/15000], training loss: 0.2487
# [4/15000], training loss: 0.2086
# [6/15000], training loss: 0.1764
# [8/15000], training loss: 0.1431
# model saved to ../results/AVD/Z_AVD_Home_015_1_traj7/model_best.pth
# Z_AVD_Home_015_1_traj7, ate: 785.3926673924796
# [10/15000], training loss: 0.1389
# [12/15000], training loss: 0.1308
# [14/15000], training loss: 0.1353
# [16/15000], training loss: 0.1318
# model saved to ../results/AVD/Z_AVD_Home_015_1_traj7/model_best.pth
# Z_AVD_Home_015_1_traj7, ate: 639.8874906334999
# [18/15000], training loss: 0.1333
# [20/15000], training loss: 0.1278
# ...

# %%
# !./run_train_AVD.sh 8
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj8', scene_index=8, subsample_rate=40, traj='traj8.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj8.txt'

# %%
# !./run_train_AVD.sh 9
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj9', scene_index=9, subsample_rate=40, traj='traj9.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj9.txt'

# %%
# !./run_train_AVD.sh 10
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj10', scene_index=10, subsample_rate=40, traj='traj10.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj10.txt'

# %%
# !./run_train_AVD.sh 11
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj11', scene_index=11, subsample_rate=40, traj='traj11.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj11.txt'

# %%
# !./run_train_AVD.sh 12
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj12', scene_index=12, subsample_rate=40, traj='traj12.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj12.txt'

# %%
# !./run_train_AVD.sh 13
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj13', scene_index=13, subsample_rate=40, traj='traj13.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj13.txt'

# %%
# !./run_train_AVD.sh 14
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj14', scene_index=14, subsample_rate=40, traj='traj14.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj14.txt'

# %%
# !./run_train_AVD.sh 15
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj15', scene_index=15, subsample_rate=40, traj='traj15.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj15.txt'

# %%
# !./run_train_AVD.sh 16
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj16', scene_index=16, subsample_rate=40, traj='traj16.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj16.txt'

# %%
# !./run_train_AVD.sh 17
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj17', scene_index=17, subsample_rate=40, traj='traj17.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj17.txt'

# %%
# !./run_train_AVD.sh 18
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj18', scene_index=18, subsample_rate=40, traj='traj18.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj18.txt'

# %%
# !./run_train_AVD.sh 19
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj19', scene_index=19, subsample_rate=40, traj='traj19.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj19.txt'

# %%
# !./run_train_AVD.sh 20
# Out:
# Namespace(batch_size=16, conv_size=16, data_dir='/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1', latent_size=16, log_interval=2, loss='bce_ch', lr=0.001, mode='simgle', model=None, n_epochs=15000, n_samples=35, name='Z_AVD_Home_015_1_traj20', scene_index=20, subsample_rate=40, traj='traj20.txt')
# latent size single: 16
# loading dataset
# Traceback (most recent call last):
#   File "train_AVD.py", line 69, in <module>
#     dataset = AVDtrain(opt.data_dir,opt.traj,instances_per_scene,opt.subsample_rate)
#   File "../dataset_loader/AVDtrain.py", line 33, in __init__
#     depth_files = [line.rstrip('\n') for line in open(traj_file)]
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmvc/mmvc-ny-nas/Yi_Shi/data/ActiveVisionDataset/Home_015_1/local_point_cloud/traj20.txt'
